# %%
# %load_ext autoreload
# %autoreload 2

import os
os.environ["HF_HUB_OFFLINE"] = "1" # uncomment after downloading
from src.rank import rank
import src.utils.config as cfg

if __name__ == '__main__':
    ds = "wikir"
    cfg.init(ds)
    rank(queries=100, use_refine=True, compare_faiss=True)

# %%
# %load_ext autoreload
# %autoreload 2

import os
os.environ["HF_HUB_OFFLINE"] = "1" # uncomment after downloading
from src.rank import rank
import src.utils.config as cfg

if __name__ == '__main__':
    ds = "quora"
    cfg.init(ds)
    rank(queries=5000, use_refine=False, compare_faiss=False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# init... beir/quora/dev
# done init.
# Processing Queries: 100%|██████████| 5000/5000 [05:58<00:00, 13.97it/s]
# Computing evaluation metrics...
#
# 	=== PERFORMANCE COMPARISON TABLE ===
#            Model      MAP    P@10  Recall@10  nDCG@10
#           TF-IDF 0.668462 0.10754   0.805965 0.707066
#             BM25 0.703121 0.11392   0.849697 0.744732
#             BERT 0.834606 0.13090   0.936720 0.865427
#    Hybrid Serial 0.828921 0.12844   0.927332 0.860711
#  Hybrid Parallel 0.822937 0.13022   0.942473 0.858295
#   Refined TF-IDF 0.000000 0.00000   0.000000 0.000000
#     Refined BM25 0.000000 0.00000   0.000000 0.000000
#   Refined Serial 0.000000 0.00000   0.000000 0.000000
# Refined Parallel 0.000000 0.00000   0.000000 0.000000
